# %%
import netCDF4
#import h5netcdf
import xarray as xr
import scipy
import os
import numpy as np
import xeofs as xeo
import scipy.stats as stats
import warnings
import matplotlib.pyplot as plt
import scipy.signal as signal
import pandas as pd
import cartopy.crs as ccrs
import cartopy
import seaborn as sns
import xskillscore as xsc


def fix_coords_lon(ds):
    ds = ds.assign_coords(longitude=(((ds.longitude + 180) % 360) - 180)).sortby(['longitude','latitude'])
    return ds

def fix_coords_lon_lat(ds):
    ds = ds.assign_coords(lon=(((ds.lon + 180) % 360) - 180)).sortby(['lon','lat'])
    return ds

wusbox = [-125, -102, 32,  49]

# %%
import json
modmembers_valid_pyrte = {}
with open('/home/tessj/wus_temp_trends/modmembers_trendwithin5wm2_pyrte_lwd_clr.json', 'r') as file:
        modmembers_valid_pyrte = json.load(file)

# %%
ERA5_lwd_jfm_trend = np.float64(-1.7236339743757363)
ERA5_lwd_clr_jfm_trend = 0.7375459656228737
ERA5_pyrte_lwd = np.float64(-2.200686819945355)
ERA5_pyrte_lwd_temp1980 = np.float64(-2.2495023118862996)

# %%
ds_lwd_avg = xr.open_dataset('/home/tessj/wus_temp_trends/cmip6_ensmean_lwd_avgs.nc')

ds_lwd_avg_51_80_m_clim = ds_lwd_avg.sel(time=slice('1951-01-01', '1980-12-31')).groupby('time.month').mean('time')
ds_lwd_avg_51_80_m_anom = ds_lwd_avg.groupby('time.month') - ds_lwd_avg_51_80_m_clim

ds_lwd_avg_51_80_m_anom_szn = {}

for i, szn in enumerate(['JFM', 'AMJ', 'JAS', 'OND']):
    ds_lwd_avg_51_80_m_anom_szn[szn] = ds_lwd_avg_51_80_m_anom.resample(time='QS-JAN').mean('time').isel(time=slice(i,None,4))
    
ds_lwd_avg_51_80_m_anom_trend_szn = {}

for i, szn in enumerate(['JFM', 'AMJ', 'JAS', 'OND']):
    ds_lwd_avg_51_80_m_anom_trend_szn[szn] = ds_lwd_avg_51_80_m_anom_szn[szn].sel(time=slice('1980-01-01','2024-01-01')).groupby('time.year').mean('time').polyfit(dim='year', deg=1).sel(degree=1)

# %%
ds_lwd_clr_avg = xr.open_dataset('/home/tessj/wus_temp_trends/cmip6_ensmean_rldscs_avgs.nc')

ds_lwd_clr_avg_51_80_m_clim = ds_lwd_clr_avg.sel(time=slice('1951-01-01', '1980-12-31')).groupby('time.month').mean('time')
ds_lwd_clr_avg_51_80_m_anom = ds_lwd_clr_avg.groupby('time.month') - ds_lwd_clr_avg_51_80_m_clim

ds_lwd_clr_avg_51_80_m_anom_szn = {}

for i, szn in enumerate(['JFM', 'AMJ', 'JAS', 'OND']):
    ds_lwd_clr_avg_51_80_m_anom_szn[szn] = ds_lwd_clr_avg_51_80_m_anom.resample(time='QS-JAN').mean('time').isel(time=slice(i,None,4))
    
ds_lwd_clr_avg_51_80_m_anom_trend_szn = {}

for i, szn in enumerate(['JFM', 'AMJ', 'JAS', 'OND']):
    ds_lwd_clr_avg_51_80_m_anom_trend_szn[szn] = ds_lwd_clr_avg_51_80_m_anom_szn[szn].sel(time=slice('1980-01-01','2024-01-01')).groupby('time.year').mean('time').polyfit(dim='year', deg=1).sel(degree=1)

# %%
ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].rldscs_wus_polyfit_coefficients
# Out:
# <xarray.DataArray 'rldscs_wus_polyfit_coefficients' (model: 21)>
# array([0.14209202, 0.15713573, 0.19098694, 0.20542944, 0.18885609,
#        0.19698161, 0.1202443 , 0.19132613, 0.17309011, 0.16934262,
#        0.18870408, 0.21007854, 0.26926514, 0.14834931, 0.14666953,
#        0.13541279, 0.22230423, 0.17953415, 0.19742419, 0.18978279,
#        0.1385608 ])
# Coordinates:
#   * model    (model) object 'CNRM-CM6-1' 'IPSL-CM6A-LR' ... 'GISS-E2-1-G'
#     degree   int64 1

# %%
set(ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].model.values) - set(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].model.values)
# Out:
# {'EC-Earth3-Veg-LR', 'GISS-E2-1-H'}

# %%
set(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].model.values) - set(ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].model.values)
# Out:
# {'GFDL-ESM4', 'NorESM2-LM'}

# %%
set(modmembers_pl_all.keys()) - set(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].model.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 set(modmembers_pl_all.keys()) - set(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].model.values)
#
# NameError: name 'modmembers_pl_all' is not defined

# %%
with open('/home/tessj/wus_temp_trends/modmembers_allvars_WUS_subset_forpyrte.json', 'r') as file:
        modmembers_pl_all = json.load(file)

# %%
modmembers_lwd_all = list(set(ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].model.values) & set(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].model.values))
modmembers_lwd_all = [model for model in modmembers_lwd_all if (model != 'FGOALS-g3')]

# %%
cmip6_ensmean_pyrte_clr_lwd_trend = []
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend = []
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend = []
cmip6_ensmean_pyrte_clr_lwd_q1980_trend = []
cmip6_ensmean_lwd_clr = []
cmip6_ensmean_lwd = []


for model in modmembers_lwd_all :
    print(model)
    cmip6_ensmean_pyrte_clr_lwd_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members.nc').polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend.nc').polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend_era5h2otrend.nc').polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_pyrte_clr_lwd_q1980_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_q1980.nc').polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_lwd_clr.append(ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].sel(model=model).rldscs_wus_polyfit_coefficients.item())
    cmip6_ensmean_lwd.append(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].sel(model=model).lwd_wus_polyfit_coefficients.item())
# Out:
# FIO-ESM-2-0
# IPSL-CM6A-LR
# MIROC6
# EC-Earth3
# GISS-E2-1-G
# UKESM1-0-LL
# CESM2
# EC-Earth3-Veg
# MPI-ESM1-2-LR
# KACE-1-0-G
# CNRM-CM6-1
# MRI-ESM2-0
# CNRM-ESM2-1
# CanESM5-CanOE
# CESM2-WACCM
# MIROC-ES2L
# CanESM5

# %%
test = xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/MRI-ESM2-0_lwd_members_tempdetrend_era5h2otrend.nc')#.sel(member_id = modmembers_valid_pyrte['MRI-ESM2-0'])
#3xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/MRI-ESM2-0_lwd_members.nc@')

# %%
45*test.polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients
# Out:
# <xarray.DataArray 'h2o_polyfit_coefficients' (member_id: 5)>
# array([ 1.19966586,  5.09873924, -3.24207855,  0.6134033 , -8.17245588])
# Coordinates:
#   * member_id  (member_id) object 'r3i1p1f1' 'r2i1p1f1' ... 'r5i1p1f1'
#     degree     int64 1

# %%
45*test.polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.sel(member_id = modmembers_valid_pyrte['MRI-ESM2-0'])
# Out:
# <xarray.DataArray 'h2o_polyfit_coefficients' (member_id: 4)>
# array([ 0.6134033 ,  5.09873924,  1.19966586, -3.24207855])
# Coordinates:
#   * member_id  (member_id) object 'r1i1p1f1' 'r2i1p1f1' 'r3i1p1f1' 'r4i1p1f1'
#     degree     int64 1

# %%
models_fig4 = ['GFDL-ESM4', 'IPSL-CM6A-LR', 'CNRM-CM6-1', 'MRI-ESM2-0',
       'CNRM-ESM2-1', 'CanESM5', 'CanESM5-CanOE', 'UKESM1-0-LL', 'MIROC6',
       'MPI-ESM1-2-LR', 'CESM2-WACCM', 'FGOALS-g3', 'MIROC-ES2L',
       'NorESM2-LM', 'ACCESS-CM2', 'KACE-1-0-G', 'FIO-ESM-2-0',
       'GISS-E2-1-G', 'EC-Earth3-Veg', 'EC-Earth3', 'CESM2']

# %%
modmembers_valid_pyrte.keys()
# Out:
# dict_keys(['CNRM-CM6-1', 'IPSL-CM6A-LR', 'EC-Earth3-Veg', 'CanESM5-CanOE', 'MIROC6', 'MRI-ESM2-0', 'MPI-ESM1-2-LR', 'FIO-ESM-2-0', 'ACCESS-CM2', 'FGOALS-g3', 'EC-Earth3', 'CESM2', 'CESM2-WACCM', 'MIROC-ES2L', 'CNRM-ESM2-1', 'CanESM5', 'KACE-1-0-G', 'UKESM1-0-LL', 'GISS-E2-1-G'])

# %%
## SELECT ONLY FOR "VALID" MODELS
cmip6_ensmean_pyrte_clr_lwd_trend = []
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend = []
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend = []
cmip6_ensmean_pyrte_clr_lwd_q1980_trend = []
cmip6_ensmean_lwd_clr = []
cmip6_ensmean_lwd = []


#for model in modmembers_lwd_all :
for model in modmembers_valid_pyrte:
    print(model)
    cmip6_ensmean_pyrte_clr_lwd_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend_era5h2otrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_pyrte_clr_lwd_q1980_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_q1980.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    cmip6_ensmean_lwd_clr.append(ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].sel(model=model).rldscs_wus_polyfit_coefficients.item())
    cmip6_ensmean_lwd.append(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].sel(model=model).lwd_wus_polyfit_coefficients.item())
# Out:
# CNRM-CM6-1
# IPSL-CM6A-LR
# EC-Earth3-Veg
# CanESM5-CanOE
# MIROC6
# MRI-ESM2-0
# MPI-ESM1-2-LR
# FIO-ESM-2-0
# ACCESS-CM2
# FGOALS-g3
# EC-Earth3
# CESM2
# CESM2-WACCM
# MIROC-ES2L
# CNRM-ESM2-1
# CanESM5
# KACE-1-0-G
# UKESM1-0-LL
# GISS-E2-1-G
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      11 for model in modmembers_valid_pyrte:
#      12     print(model)
# ---> 13     cmip6_ensmean_pyrte_clr_lwd_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
#      14     cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
#      15     cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend_era5h2otrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
#
# File ~/miniconda3/envs/cmip6-tess/lib/python3.10/site-packages/xarray/core/dataset.py:7878, in Dataset.polyfit(self, dim, deg, skipna, rcond, w, full, cov)
#    7876 if dims_to_stack:
#    7877     stacked_dim = utils.get_temp_dimname(dims_to_stack, "stacked")
# -> 7878     rhs = da.transpose(dim, *dims_to_stack).stack(
#    7879         {stacked_dim: dims_to_stack}
#    7880     )
#    7881     stacked_coords = {stacked_dim: rhs[stacked_dim]}
#    7882     scale_da = scale[:, np.newaxis]
#
# File ~/miniconda3/envs/cmip6-tess/lib/python3.10/site-packages/xarray/core/dataarray.py:2743, in DataArray.stack(self, dimensions, create_index, index_cls, **dimensions_kwargs)
#    2678 def stack(
#    2679     self: T_DataArray,
#    2680     dimensions: Mapping[Any, Sequence[Hashable]] | None = None,
#    (...)
#    2683     **dimensions_kwargs: Sequence[Hashable],
#    2684 ) -> T_DataArray:
#    2685     """
#    2686     Stack any number of existing dimensions into a single new dimension.
#    2687
#    (...)
#    2741     DataArray.unstack
#    2742     """
# -> 2743     ds = self._to_temp_dataset().stack(
#    2744         dimensions,
#    2745         create_index=create_index,
#    2746         index_cls=index_cls,
#    2747         **dimensions_kwargs,
#    2748     )
#    2749     return self._from_temp_dataset(ds)
#
# File ~/miniconda3/envs/cmip6-tess/lib/python3.10/site-packages/xarray/core/dataarray.py:530, in DataArray._to_temp_dataset(self)
#     529 def _to_temp_dataset(self) -> Dataset:
# --> 530     return self._to_dataset_whole(name=_THIS_ARRAY, shallow_copy=False)
#
# File ~/miniconda3/envs/cmip6-tess/lib/python3.10/site-packages/xarray/core/dataarray.py:582, in DataArray._to_dataset_whole(self, name, shallow_copy)
#     579 indexes = self._indexes
#     581 coord_names = set(self._coords)
# --> 582 return Dataset._construct_direct(variables, coord_names, indexes=indexes)
#
# File ~/miniconda3/envs/cmip6-tess/lib/python3.10/site-packages/xarray/core/dataset.py:973, in Dataset._construct_direct(cls, variables, coord_names, dims, attrs, indexes, encoding, close)
#     969 """Shortcut around __init__ for internal use when we want to skip
#     970 costly validation
#     971 """
#     972 if dims is None:
# --> 973     dims = calculate_dimensions(variables)
#     974 if indexes is None:
#     975     indexes = {}
#
# File ~/miniconda3/envs/cmip6-tess/lib/python3.10/site-packages/xarray/core/variable.py:3231, in calculate_dimensions(variables)
#    3229             last_used[dim] = k
#    3230         elif dims[dim] != size:
# -> 3231             raise ValueError(
#    3232                 f"conflicting sizes for dimension {dim!r}: "
#    3233                 f"length {size} on {k!r} and length {dims[dim]} on {last_used!r}"
#    3234             )
#    3235 return dims
#
# ValueError: conflicting sizes for dimension 'year': length 1 on <this-array> and length 45 on {'member_id': 'member_id', 'year': 'year'}

# %%
modmembers_valid_pyrte.keys()

# %%
## SELECT ONLY FOR "VALID" MODELS
cmip6_ensmean_pyrte_clr_lwd_trend = []
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend = []
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend = []
cmip6_ensmean_pyrte_clr_lwd_era5h2otrend_trend = []

cmip6_ensmean_pyrte_clr_lwd_q1980_trend = []
cmip6_ensmean_lwd_clr = []
cmip6_ensmean_lwd = []


#for model in modmembers_lwd_all :
for model in models_fig4:
    print(model)
    if model in list(modmembers_valid_pyrte.keys())[:-1]:
        cmip6_ensmean_pyrte_clr_lwd_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
        cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
        cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_tempdetrend_era5h2otrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
        cmip6_ensmean_pyrte_clr_lwd_q1980_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_q1980.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
        cmip6_ensmean_lwd_clr.append(ds_lwd_clr_avg_51_80_m_anom_trend_szn['JFM'].sel(model=model).rldscs_wus_polyfit_coefficients.item())
        cmip6_ensmean_lwd.append(ds_lwd_avg_51_80_m_anom_trend_szn['JFM'].sel(model=model).lwd_wus_polyfit_coefficients.item())
        cmip6_ensmean_pyrte_clr_lwd_era5h2otrend_trend.append(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members_era5h2otrend.nc').sel(member_id = modmembers_valid_pyrte[model]).polyfit(dim='year', deg=1).sel(degree=1).h2o_polyfit_coefficients.mean('member_id').item())
    else:
        cmip6_ensmean_pyrte_clr_lwd_trend.append(np.nan)
        cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend.append(np.nan)
        cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend.append(np.nan)
        cmip6_ensmean_pyrte_clr_lwd_q1980_trend.append(np.nan)
        cmip6_ensmean_pyrte_clr_lwd_era5h2otrend_trend.append(np.nan)
        cmip6_ensmean_lwd_clr.append(np.nan)
        cmip6_ensmean_lwd.append(np.nan)
# Out:
# GFDL-ESM4
# IPSL-CM6A-LR
# CNRM-CM6-1
# MRI-ESM2-0
# CNRM-ESM2-1
# CanESM5
# CanESM5-CanOE
# UKESM1-0-LL
# MIROC6
# MPI-ESM1-2-LR
# CESM2-WACCM
# FGOALS-g3
# MIROC-ES2L
# NorESM2-LM
# ACCESS-CM2
# KACE-1-0-G
# FIO-ESM-2-0
# GISS-E2-1-G
# EC-Earth3-Veg
# EC-Earth3
# CESM2

# %%
modmembers_valid_pyrte.keys()
# Out:
# dict_keys(['CNRM-CM6-1', 'IPSL-CM6A-LR', 'EC-Earth3-Veg', 'CanESM5-CanOE', 'MIROC6', 'MRI-ESM2-0', 'MPI-ESM1-2-LR', 'FIO-ESM-2-0', 'FGOALS-g3', 'EC-Earth3', 'CESM2', 'CESM2-WACCM', 'MIROC-ES2L', 'CNRM-ESM2-1', 'CanESM5', 'KACE-1-0-G', 'UKESM1-0-LL', 'GISS-E2-1-G'])

# %%
xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/FGOALS-g3_lwd_members_tempdetrend.nc').isel(member_id=1).h2o.plot()

# %%
xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/FGOALS-g3_lwd_members.nc').isel(member_id=1).h2o.std()
# Out:
# <xarray.DataArray 'h2o' ()>
# array(32.3867336)
# Coordinates:
#     member_id  <U8 'r2i1p1f1'
#     model      object ...

# %%
for model in modmembers_lwd_all:
    print(model)
    print(xr.open_dataset(f'/home/tessj/wus_temp_trends/pyRTE-RRTMGP/examples/CMIP6_LWD_sfc_clr/{model}_lwd_members.nc').h2o.std('year'))
# Out:
# EC-Earth3
# <xarray.DataArray 'h2o' (member_id: 19)>
# array([7.29243447, 5.87426768, 7.53864138, 6.38415707, 6.2669082 ,
#        7.84239624, 5.83652357, 6.06114502, 6.33743054, 6.90418818,
#        6.3108819 , 6.74775783, 6.52556357, 6.34534809, 6.48033288,
#        6.69222128, 6.04558296, 7.64162346, 7.78083311])
# Coordinates:
#   * member_id  (member_id) object 'r6i1p1f1' 'r14i1p1f1' ... 'r16i1p1f1'
#     model      object ...
# EC-Earth3-Veg
# <xarray.DataArray 'h2o' (member_id: 7)>
# array([6.8745534 , 5.30104405, 6.75513179, 8.65527789, 6.52777577,
#        6.48083158, 6.7457626 ])
# Coordinates:
#   * member_id  (member_id) object 'r12i1p1f1' 'r1i1p1f1' ... 'r14i1p1f1'
#     model      object ...
# KACE-1-0-G
# <xarray.DataArray 'h2o' (member_id: 3)>
# array([7.59868819, 7.36230262, 6.35927658])
# Coordinates:
#   * member_id  (member_id) object 'r1i1p1f1' 'r2i1p1f1' 'r3i1p1f1'
#     model      object ...
# MIROC-ES2L
# <xarray.DataArray 'h2o' (member_id: 16)>
# array([4.73434936, 4.8223024 , 5.19799611, 5.52658402, 4.42203878,
#        4.95170812, 4.40707775, 4.98680175, 5.02371788, 4.72967927,
#        5.03872859, 4.46339664, 6.1510628 , 5.56344294, 4.73926519,
#        5.73840273])
# Coordinates:
#   * member_id  (member_id) object 'r26i1p1f2' 'r3i1p1f2' ... 'r9i1p1f2'
#     model      object ...
# MPI-ESM1-2-LR
# <xarray.DataArray 'h2o' (member_id: 9)>
# array([6.36186414, 6.88982544, 5.60527945, 6.75159668, 6.45946972,
#        5.46445147, 5.39231391, 5.43286158, 6.8340691 ])
# Coordinates:
#   * member_id  (member_id) object 'r10i1p1f1' 'r2i1p1f1' ... 'r5i1p1f1'
#     model      object ...
# CESM2-WACCM
# <xarray.DataArray 'h2o' (member_id: 3)>
# array([6.38664445, 5.97456621, 5.5890795 ])
# Coordinates:
#   * member_id  (member_id) object 'r1i1p1f1' 'r2i1p1f1' 'r3i1p1f1'
#     model      object ...
# FIO-ESM-2-0
# <xarray.DataArray 'h2o' (member_id: 3)>
# array([5.57528257, 6.37123216, 7.10925394])
# Coordinates:
#   * member_id  (member_id) object 'r1i1p1f1' 'r2i1p1f1' 'r3i1p1f1'
#     model      object ...
# CanESM5-CanOE
# <xarray.DataArray 'h2o' (member_id: 3)>
# array([8.50855714, 8.05214245, 6.77915285])
# Coordinates:
#   * member_id  (member_id) object 'r1i1p2f1' 'r3i1p2f1' 'r2i1p2f1'
#     model      object ...
# CESM2
# <xarray.DataArray 'h2o' (member_id: 3)>
# array([5.16938207, 5.47212432, 5.31176032])
# Coordinates:
#   * member_id  (member_id) object 'r11i1p1f1' 'r10i1p1f1' 'r4i1p1f1'
#     model      object ...
# CNRM-ESM2-1
# <xarray.DataArray 'h2o' (member_id: 9)>
# array([16.80262446, 12.32005432, 10.18121475, 10.52120582, 15.25670828,
#         9.34162979, 14.18836324, 12.95167407,  9.9718343 ])
# Coordinates:
#   * member_id  (member_id) object 'r3i1p1f2' 'r10i1p1f2' ... 'r9i1p1f2'
#     model      object ...
# IPSL-CM6A-LR
# <xarray.DataArray 'h2o' (member_id: 11)>
# array([7.46225876, 8.21747939, 6.70670345, 7.5789668 , 6.72118382,
#        7.34174593, 8.18131423, 6.83574853, 7.61653219, 6.93903628,
#        8.14998875])
# Coordinates:
#   * member_id  (member_id) object 'r10i1p1f1' 'r2i1p1f1' ... 'r11i1p1f1'
#     model      object ...
# MIROC6
# <xarray.DataArray 'h2o' (member_id: 50)>
# array([17.09916508, 20.71472031, 17.79161253, 19.11923233, 19.67563975,
#        17.88043685, 16.60189126, 18.23390325, 19.82362594, 17.94802476,
#        19.92340969, 17.6677924 , 18.15043353, 20.30488582, 20.66469565,
#        17.6070879 , 17.87707305, 14.4403429 , 18.43015665, 16.60571763,
#        19.97573896, 16.56527963, 20.03208424, 16.74896882, 18.80395847,
#        18.31579044, 16.76371646, 16.6782907 , 20.32775553, 19.13050264,
#        15.57822155, 19.26015785, 17.93101691, 19.14303129, 17.28982629,
#        18.96223426, 18.91407271, 16.47944178, 19.10607172, 17.44460184,
#        18.26501414, 18.87697156, 18.6334192 , 19.53826599, 19.36528805,
#        19.64957827, 18.88239254, 18.88646329, 21.02684185, 20.85994371])
# Coordinates:
#   * member_id  (member_id) object 'r47i1p1f1' 'r32i1p1f1' ... 'r28i1p1f1'
#     model      object ...
# CanESM5
# <xarray.DataArray 'h2o' (member_id: 50)>
# array([8.14095051, 6.85680583, 7.29194344, 9.64425149, 8.20785108,
#        7.89126869, 7.50872112, 8.95575374, 8.14315148, 7.1770752 ,
#        7.06149442, 7.43704056, 7.90265416, 8.35070783, 8.45034321,
#        8.07102411, 8.05527862, 8.22263319, 8.05214245, 6.77915285,
#        7.87241222, 7.58325958, 6.7719722 , 8.02623361, 8.9171574 ,
#        7.55000501, 9.24635608, 7.54171863, 7.92417442, 8.57380964,
#        7.74873155, 6.32327451, 9.23723462, 7.69436862, 7.04957693,
#        7.73042059, 8.0130239 , 7.56201281, 8.07647302, 8.44390692,
#        7.21645358, 8.22652424, 7.52130395, 8.50855714, 8.44447928,
#        7.06765152, 6.61807227, 6.88032373, 7.89275514, 6.80516931])
# Coordinates:
#   * member_id  (member_id) object 'r6i1p2f1' 'r6i1p1f1' ... 'r16i1p1f1'
#     model      object ...
# MRI-ESM2-0
# <xarray.DataArray 'h2o' (member_id: 5)>
# array([17.63339674, 18.17055663, 11.67710905, 12.29362173, 11.13445597])
# Coordinates:
#   * member_id  (member_id) object 'r2i1p1f1' 'r1i1p1f1' ... 'r5i1p1f1'
#     model      object ...
# FGOALS-g3
# <xarray.DataArray 'h2o' (member_id: 4)>
# array([33.16927017, 32.3867336 , 32.3763328 , 30.17017069])
# Coordinates:
#   * member_id  (member_id) object 'r1i1p1f1' 'r2i1p1f1' 'r4i1p1f1' 'r3i1p1f1'
#     model      object ...
# UKESM1-0-LL
# <xarray.DataArray 'h2o' (member_id: 6)>
# array([6.22711361, 6.23852816, 8.4836107 , 6.85589344, 7.51579651,
#        6.67802997])
# Coordinates:
#   * member_id  (member_id) object 'r3i1p1f2' 'r4i1p1f2' ... 'r8i1p1f2'
#     model      object ...
# GISS-E2-1-G
# <xarray.DataArray 'h2o' (member_id: 14)>
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan])
# Coordinates:
#   * member_id  (member_id) object 'r10i1p1f2' 'r4i1p3f1' ... 'r2i1p5f1'
#     model      object ...
# CNRM-CM6-1
# <xarray.DataArray 'h2o' (member_id: 6)>
# array([11.66109193, 10.63484844, 10.18154225,  9.24878367,  7.57028666,
#        12.90670568])
# Coordinates:
#   * member_id  (member_id) object 'r3i1p1f2' 'r4i1p1f2' ... 'r1i1p1f2'
#     model      object ...

# %%
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend
# Out:
# [-0.02013335099290331,
#  -0.05583840403416929,
#  -0.05784570797463735,
#  -0.05640118944960112,
#  -0.005709785242777192,
#  0.020387388064858493,
#  -0.0537458288186383,
#  -0.0533216109571504,
#  -0.015146423210289594,
#  -0.0586129766554457,
#  -0.023338798710833553,
#  -0.02507946404338669,
#  -0.024310662637363645,
#  -0.013754247884680215,
#  -0.05667411227795146,
#  -0.0538640604059778,
#  -0.05650754016097998]

# %%
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend
# Out:
# [0.06991579436477993,
#  0.048206916349994994,
#  0.06156292779694243,
#  0.06319407645973606,
#  0.0872199091324947,
#  0.1268824274358487,
#  0.02481084455926462,
#  0.06698892384550918,
#  0.08833300802016616,
#  0.04899002386836946,
#  0.05593746350702827,
#  0.050807420133445545,
#  0.03576829494802621,
#  0.07161347618503126,
#  0.0642364145351897,
#  0.057476398533336436,
#  0.06816834612984488]

# %%
45*np.nanmean(cmip6_ensmean_pyrte_clr_lwd_q1980_trend)
# Out:
# 3.0545766679038335

# %%
cmip6_ensmean_pyrte_df = pd.DataFrame(cmip6_ensmean_pyrte_clr_lwd_trend, columns = ['CMIP6 T, q'])
cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, q'] = cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend
cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, ERA5 q trend'] = cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend
cmip6_ensmean_pyrte_df['CMIP6 T, ERA5 q trend'] = cmip6_ensmean_pyrte_clr_lwd_era5h2otrend_trend

cmip6_ensmean_pyrte_df['CMIP6 clear-sky LWD'] = cmip6_ensmean_lwd_clr
cmip6_ensmean_pyrte_df['CMIP6 LWD'] = cmip6_ensmean_lwd

# %%
np.nanmean(cmip6_ensmean_pyrte_clr_lwd_trend)
# Out:
# 0.13869424898592153

# %%
sns.catplot(45*cmip6_ensmean_pyrte_df)

# %%
ERA5_lwd_jfm_trend = np.float64(-1.7236339743757363)
ERA5_lwd_clr_jfm_trend = 0.7375459656228737
ERA5_pyrte_lwd = np.float64(-2.200686819945355)
ERA5_pyrte_lwd_temp1980 = np.float64(-2.2495023118862996)
ERA5_pyrte_lwd_tempdetrend = np.float64(-2.263649909123405)

# %%
cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend
# Out:
# [-0.02013335099290331,
#  -0.05583840403416929,
#  -0.05784570797463735,
#  -0.05640118944960112,
#  -0.005709785242777192,
#  0.020387388064858493,
#  -0.0537458288186383,
#  -0.0533216109571504,
#  -0.015146423210289594,
#  -0.0586129766554457,
#  -0.023338798710833553,
#  -0.02507946404338669,
#  -0.024310662637363645,
#  -0.013754247884680215,
#  -0.05667411227795146,
#  -0.0538640604059778,
#  -0.05650754016097998]

# %%
cmip6_ensmean_pyrte_clr_lwd_era5h2otrend_trend
# Out:
# [nan,
#  0.026956637707814302,
#  0.049371025144051985,
#  0.1046867445406956,
#  0.04468262034002101,
#  0.08486926651272322,
#  0.0699353372937094,
#  0.058056128349183854,
#  0.0662527070381472,
#  0.007169848175201229,
#  0.10772429033435184,
#  0.08843074727468186,
#  0.03340270695936417,
#  nan,
#  0.03858652531404552,
#  0.08018573900291616,
#  0.05657275899632345,
#  nan,
#  0.02612314895120596,
#  0.03139129610456419,
#  0.05623517344209485]

# %%
barplot_df = pd.DataFrame([{'ERA5 LWD':ERA5_lwd_jfm_trend, 'ERA5 clear-sky LWD':ERA5_lwd_clr_jfm_trend,
                            'CMIP6 LWD':45*np.nanmean(cmip6_ensmean_lwd),'CMIP6 clear-sky LWD':45*np.nanmean(cmip6_ensmean_lwd_clr), 
                            'ERA5 T, q':ERA5_pyrte_lwd, 'ERA5 $\overline{T}$, q':ERA5_pyrte_lwd_tempdetrend, 
                           'CMIP6 T, q':45*np.nanmean(cmip6_ensmean_pyrte_clr_lwd_trend),
                            'CMIP6 T, ERA5 q trend':45*np.nanmean(cmip6_ensmean_pyrte_clr_lwd_era5h2otrend_trend),
                           'CMIP6 $\overline{T}$, q': 45*np.nanmean(cmip6_ensmean_pyrte_clr_lwd_tempdetrend_trend),
                           'CMIP6 $\overline{T}$, ERA5 q trend': 45*np.nanmean(cmip6_ensmean_pyrte_clr_lwd_tempdetrend_era5h2otrend_trend)}])

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df, palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df, marker = 'o', edgecolor='k', color='white',linewidth=1, size=4)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE modeled LWD', x=3.55, y=12)
# Out:
# Text(3.55, 12, 'pyRTE modeled LWD')

# %%
barplot_df.iloc[:, [0, 1,2,3, 6,8,9]]
# Out:
#    ERA5 LWD  ERA5 clear-sky LWD  CMIP6 LWD  CMIP6 clear-sky LWD  CMIP6 T, q
# 0 -1.723634            0.737546   7.299823             8.244535    7.064881  \
#
#    CMIP6 $\overline{T}$, q  CMIP6 $\overline{T}$, ERA5 q trend
# 0                 2.830312                           -1.658206

# %%
cmip6_ensmean_pyrte_df
# Out:
#     CMIP6 T, q  CMIP6 $\overline{T}$, q  CMIP6 $\overline{T}$, ERA5 q trend
# 0          NaN                      NaN                                 NaN  \
# 1     0.130998                 0.048207                           -0.055838
# 2     0.139414                 0.069916                           -0.020133
# 3     0.211172                 0.126882                            0.020387
# 4     0.130045                 0.071613                           -0.013754
# 5     0.205778                 0.064236                           -0.056674
# 6     0.189526                 0.063194                           -0.056401
# 7     0.182729                 0.068168                           -0.056508
# 8     0.159179                 0.087220                           -0.005710
# 9     0.085725                 0.024811                           -0.053746
# 10    0.183604                 0.050807                           -0.025079
# 11    0.191903                 0.088333                           -0.015146
# 12    0.093481                 0.035768                           -0.024311
# 13         NaN                      NaN                                 NaN
# 14    0.133982                 0.042012                           -0.053386
# 15    0.191516                 0.057476                           -0.053864
# 16    0.176881                 0.066989                           -0.053322
# 17         NaN                      NaN                                 NaN
# 18    0.145535                 0.061563                           -0.057846
# 19    0.138995                 0.048990                           -0.058613
# 20    0.135488                 0.055937                           -0.023339
#
#     CMIP6 T, ERA5 q trend  CMIP6 clear-sky LWD  CMIP6 LWD
# 0                     NaN                  NaN        NaN
# 1                0.026957             0.157136   0.146779
# 2                0.049371             0.142092   0.135382
# 3                0.104687             0.196982   0.141452
# 4                0.044683             0.146670   0.137965
# 5                0.084869             0.222304   0.207003
# 6                0.069935             0.205429   0.216357
# 7                0.058056             0.197424   0.177636
# 8                0.066253             0.188856   0.168734
# 9                0.007170             0.120244   0.077727
# 10               0.107724             0.269265   0.210226
# 11               0.088431             0.169343   0.198054
# 12               0.033403             0.148349   0.126548
# 13                    NaN                  NaN        NaN
# 14               0.038587             0.173090   0.088916
# 15               0.080186             0.179534   0.110092
# 16               0.056573             0.191326   0.204302
# 17                    NaN                  NaN        NaN
# 18               0.026123             0.190987   0.201630
# 19               0.031391             0.188704   0.161544
# 20               0.056235             0.210079   0.209582

# %%
cmip6_ensmean_pyrte_df.iloc[:, [0,1,2,4,5]]
# Out:
#     CMIP6 T, q  CMIP6 $\overline{T}$, q  CMIP6 $\overline{T}$, ERA5 q trend
# 0          NaN                      NaN                                 NaN  \
# 1     0.130998                 0.048207                           -0.055838
# 2     0.139414                 0.069916                           -0.020133
# 3     0.211172                 0.126882                            0.020387
# 4     0.130045                 0.071613                           -0.013754
# 5     0.205778                 0.064236                           -0.056674
# 6     0.189526                 0.063194                           -0.056401
# 7     0.182729                 0.068168                           -0.056508
# 8     0.159179                 0.087220                           -0.005710
# 9     0.085725                 0.024811                           -0.053746
# 10    0.183604                 0.050807                           -0.025079
# 11    0.191903                 0.088333                           -0.015146
# 12    0.093481                 0.035768                           -0.024311
# 13         NaN                      NaN                                 NaN
# 14    0.133982                 0.042012                           -0.053386
# 15    0.191516                 0.057476                           -0.053864
# 16    0.176881                 0.066989                           -0.053322
# 17         NaN                      NaN                                 NaN
# 18    0.145535                 0.061563                           -0.057846
# 19    0.138995                 0.048990                           -0.058613
# 20    0.135488                 0.055937                           -0.023339
#
#     CMIP6 clear-sky LWD  CMIP6 LWD
# 0                   NaN        NaN
# 1              0.157136   0.146779
# 2              0.142092   0.135382
# 3              0.196982   0.141452
# 4              0.146670   0.137965
# 5              0.222304   0.207003
# 6              0.205429   0.216357
# 7              0.197424   0.177636
# 8              0.188856   0.168734
# 9              0.120244   0.077727
# 10             0.269265   0.210226
# 11             0.169343   0.198054
# 12             0.148349   0.126548
# 13                  NaN        NaN
# 14             0.173090   0.088916
# 15             0.179534   0.110092
# 16             0.191326   0.204302
# 17                  NaN        NaN
# 18             0.190987   0.201630
# 19             0.188704   0.161544
# 20             0.210079   0.209582

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df.iloc[:, [0, 1,2,3, 6,8,9]], palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df.iloc[:, [0,1,2,4,5]], marker = 'o', edgecolor='k', color='white',linewidth=1, size=4)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center', c='maroon', fontweight='bold') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE modeled LWD', x=3.55, y=12)
# Out:
# /tmp/ipykernel_30339/2415229657.py:2: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.barplot(barplot_df.iloc[:, [0, 1,2,3, 6,8,9]], palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y', 'y'])
# Text(3.55, 12, 'pyRTE modeled LWD')

# %%
palette='colorblind'

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df.iloc[:, [0, 1,2,3, 6,8,9]], palette=['#0173b2','#0173b2', '#0173b2', '#0173b2', '#de8f05', '#de8f05', '#de8f05', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df.iloc[:, [0,1,2,4,5]], marker = 'o', edgecolor='k', color='white',linewidth=1, size=4)

for ii, container in enumerate(ax.containers):
    if ii in [0,1,6]: ax.bar_label(container, fmt='%.1f', label_type='edge', c='maroon', fontweight='bold') # 'edge' or 'center'
    else: ax.bar_label(container, fmt='%.1f', label_type='center', c='white', fontweight='bold') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE-modeled clear-sky LWD', x=3.55, y=12)
ax.text(s='ERA5/CMIP6-reported LWD', x=-0.45, y=12)
ax.set_title('Surface LWD trends', fontweight='bold', loc='left')
# Out:
# /tmp/ipykernel_22577/1424781489.py:2: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.barplot(barplot_df.iloc[:, [0, 1,2,3, 6,8,9]], palette=['#0173b2','#0173b2', '#0173b2', '#0173b2', '#de8f05', '#de8f05', '#de8f05', 'y', 'y', 'y'])
# Text(0.0, 1.0, 'Surface LWD trends')

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df, palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df, marker = 'o', edgecolor='k', color='white',linewidth=1, size=4)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE modeled LWD', x=3.55, y=12)
# Out:
# Text(3.55, 12, 'pyRTE modeled LWD')

# %%
barplot_df_v1
# Out:
#    ERA5 LWD  ERA5 clear-sky LWD  CMIP6 LWD  CMIP6 clear-sky LWD  ERA5 T, q
# 0 -1.723634            0.737546   7.493858             8.271328  -2.200687  \
#
#    ERA5 $\overline{T}$, q  CMIP6 T, q  CMIP6 $\overline{T}$, q
# 0                -2.26365    7.125803                 2.885592  \
#
#    CMIP6 $\overline{T}$, ERA5 q trend
# 0                           -1.614433

# %%
barplot_df_v1 = barplot_df.copy()
barplot_df_v1['ERA5 cloud LW effect'] = barplot_df_v1['ERA5 LWD'] - barplot_df_v1['ERA5 clear-sky LWD']
barplot_df_v1['CMIP6 cloud LW effect'] = barplot_df_v1['CMIP6 LWD'] - barplot_df_v1['CMIP6 clear-sky LWD']

# %%
barplot_discrepancy = pd.DataFrame()
barplot_discrepancy['LWD discrepancy'] = barplot_df_v1['CMIP6 LWD'] - barplot_df_v1['ERA5 LWD']
barplot_discrepancy['q trend contribution']  = barplot_df_v1['CMIP6 $\overline{T}$, q'] - barplot_df_v1['CMIP6 $\overline{T}$, ERA5 q trend'] 
barplot_discrepancy['Cloud LWD effect contribution'] = barplot_df_v1['CMIP6 cloud LW effect'] - barplot_df_v1['ERA5 cloud LW effect']

# %%
cmip6_ensmean_pyrte_df_discrepancy = pd.DataFrame()
cmip6_ensmean_pyrte_df_discrepancy['LWD discrepancy'] =  (45*cmip6_ensmean_pyrte_df['CMIP6 LWD']) - barplot_df_v1['ERA5 LWD'][0]
cmip6_ensmean_pyrte_df_discrepancy['q trend contribution'] = 45*(cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, q'] - cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, ERA5 q trend'] )
cmip6_ensmean_pyrte_df_discrepancy['Cloud LWD effect contribution'] = 45*cmip6_ensmean_pyrte_df['CMIP6 LWD'] - 45*cmip6_ensmean_pyrte_df['CMIP6 clear-sky LWD'] - barplot_df_v1['ERA5 cloud LW effect'][0]

# %%
import pickle
cmip6_ensmean_pyrte_df_discrepancy.to_pickle('/home/tessj/wus_temp_trends/cmip6_ensmean_pyrte_df_discrepancy.pkl')
barplot_discrepancy.to_pickle('/home/tessj/wus_temp_trends/cmip6_ensmean_pyrte_df_discrepancy_means.pkl')

# %%
sns.barplot(barplot_discrepancy)
sns.stripplot(cmip6_ensmean_pyrte_df_discrepancy, marker = 'o', edgecolor='k', color='white', linewidth=1)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df, palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df, marker = 'o', edgecolor='k', color='white',linewidth=1, size=4)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE modeled LWD', x=3.55, y=12)
# Out:
# Text(3.55, 12, 'pyRTE modeled LWD')

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df, palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df, marker = 'o', edgecolor='k', color='white',linewidth=1, size=4)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE modeled LWD', x=3.55, y=12)
# Out:
# Text(3.55, 12, 'pyRTE modeled LWD')

# %%
45*cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, ERA5 q trend']
# Out:
# 0    -0.906001
# 1    -2.512728
# 2    -2.603057
# 3    -2.538054
# 4    -0.256940
# 5     0.917432
# 6    -2.418562
# 7    -2.399472
# 8    -0.681589
# 9    -2.637584
# 10   -1.050246
# 11   -1.128576
# 12   -1.093980
# 13   -0.618941
# 14   -2.550335
# 15   -2.423883
# 16   -2.542839
# Name: CMIP6 $\overline{T}$, ERA5 q trend, dtype: float64

# %%
45*(cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, q'] - cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, ERA5 q trend']).mean()
# Out:
# 4.500024991403653

# %%
cmip6_ensmean_pyrte_df
# Out:
#     CMIP6 T, q  CMIP6 $\overline{T}$, q  CMIP6 $\overline{T}$, ERA5 q trend
# 0     0.139414                 0.069916                           -0.020133  \
# 1     0.130998                 0.048207                           -0.055838
# 2     0.145535                 0.061563                           -0.057846
# 3     0.189526                 0.063194                           -0.056401
# 4     0.159179                 0.087220                           -0.005710
# 5     0.211172                 0.126882                            0.020387
# 6     0.085725                 0.024811                           -0.053746
# 7     0.176881                 0.066989                           -0.053322
# 8     0.191903                 0.088333                           -0.015146
# 9     0.138995                 0.048990                           -0.058613
# 10    0.135488                 0.055937                           -0.023339
# 11    0.183604                 0.050807                           -0.025079
# 12    0.093481                 0.035768                           -0.024311
# 13    0.130045                 0.071613                           -0.013754
# 14    0.205778                 0.064236                           -0.056674
# 15    0.191516                 0.057476                           -0.053864
# 16    0.182729                 0.068168                           -0.056508
#
#     CMIP6 clear-sky LWD  CMIP6 LWD
# 0              0.142092   0.135382
# 1              0.157136   0.146779
# 2              0.190987   0.201630
# 3              0.205429   0.216357
# 4              0.188856   0.168734
# 5              0.196982   0.141452
# 6              0.120244   0.077727
# 7              0.191326   0.204302
# 8              0.169343   0.198054
# 9              0.188704   0.161544
# 10             0.210079   0.209582
# 11             0.269265   0.210226
# 12             0.148349   0.126548
# 13             0.146670   0.137965
# 14             0.222304   0.207003
# 15             0.179534   0.110092
# 16             0.197424   0.177636

# %%
cloudbiases = [ 2.15923548,  1.99512433,  2.94009748,  2.95291983,  1.55568934,
       -0.03763664,  0.54788873,  3.04509625,  3.75320442,  1.2389976 ,
        2.43882863, -0.19557265,  1.48011067,  2.0694591 ,  1.77261594,
       -0.66370547,  1.57071678]

# %%
45*(cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, q'] - cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, ERA5 q trend']) + cloudbiases
# Out:
# 0     6.211447
# 1     6.677164
# 2     8.313486
# 3     8.334707
# 4     5.737526
# 5     4.754640
# 6     4.082939
# 7     8.459070
# 8     8.409779
# 9     6.081133
# 10    6.006260
# 11    3.219337
# 12    4.183664
# 13    5.911007
# 14    7.213590
# 15    4.346615
# 16    7.181132
# dtype: float64

# %%
total_lwd_bias = 45*cmip6_ensmean_pyrte_df['CMIP6 LWD'] - -1.723634

q_contr_plus_cloudbias = 45*(cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, q'] - cmip6_ensmean_pyrte_df['CMIP6 $\overline{T}$, ERA5 q trend']) + cloudbiases

# %%
plt.scatter(x=q_contr_plus_cloudbias, y=total_lwd_bias)
plt.plot(np.arange(3,12), np.arange(3,12))

# %%
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=200)
sns.barplot(barplot_df, palette=['royalblue','royalblue', 'orange', 'orange', 'teal', 'teal', 'y', 'y', 'y'])
sns.stripplot(45*cmip6_ensmean_pyrte_df, marker = 'o', edgecolor='k', color='white',linewidth=1)

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center') # 'edge' or 'center'

    
plt.xticks(rotation=45, ha='right')
ax.axhline(0, c='grey')
ax.axvline(3.5, c='grey')
ax.set_ylabel('LWD trend [W/m2/45 years]')
ax.text(s='pyRTE modeled LWD', x=3.55, y=12)
# Out:
# Text(3.55, 12, 'pyRTE modeled LWD')
